# %%
import os
import json
from dotenv import load_dotenv

# %%
from dotenv import load_dotenv
import os

load_dotenv("API.env")
GEMINI_API_KEY = os.getenv("GEMINI_API_KEY")

print(GEMINI_API_KEY[:6])  # should print AIzaSy
# Out:
# AIzaSy

# %%
# !pip install -q google-generativeai
# Out:
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import google.generativeai as genai


genai.configure(api_key=GEMINI_API_KEY)
model = genai.GenerativeModel("gemini-1.5-flash")
response = model.generate_content(prompt)
ai_output = response.text
ai_output

# %%
student_profile = {
    "name": "Tanish Garg",
    "skills": [
        "Python",
        "Machine Learning",
        "Pandas",
        "SQL",
        "Data Analysis"
    ],
    "interests": [
        "AI",
        "Data Science",
        "Backend Development"
    ],
    "experience": "Built multiple ML projects and data analysis dashboards."
}

# %%
internship_description = {
    "role": "AI Intern",
    "required_skills": [
        "Python",
        "Machine Learning",
        "Deep Learning",
        "Docker",
        "Model Deployment"
    ],
    "description": """
    We are looking for an AI Intern to build, train and deploy machine learning models.
    Experience with Python, ML frameworks, and deployment tools is preferred.
    """
}

# %%
def calculate_ats_score(student_skills, required_skills):
    matched = set(student_skills).intersection(set(required_skills))
    score = (len(matched) / len(required_skills)) * 100
    return round(score, 2), list(matched)

# %%
ats_score, matched_skills = calculate_ats_score(
    student_profile["skills"],
    internship_description["required_skills"]
)

ats_score, matched_skills

# %%
def find_skill_gaps(student_skills, required_skills):
    return list(set(required_skills) - set(student_skills))

# %%
skill_gaps = find_skill_gaps(
    student_profile["skills"],
    internship_description["required_skills"]
)

skill_gaps

# %%
prompt = f"""
You are an AI career assistant.

Student Profile:
{json.dumps(student_profile, indent=2)}

Internship Description:
{json.dumps(internship_description, indent=2)}

Tasks:
1. Write a short internship match summary.
2. Explain skill gaps clearly.
3. Rewrite the student's resume to match the JD (do NOT add fake skills).
4. Give a final recommendation (Strong Fit / Partial Fit / Weak Fit).

Be concise and professional.
"""

# %%
from openai import OpenAI

client = OpenAI(api_key=OPENAI_API_KEY)
response = client.models.generate_content(
    model="gemini-1.5-flash",
    contents=prompt
)

ai_output = response.text
ai_output

# %%
final_output = {
    "ATS Score": ats_score,
    "Matched Skills": matched_skills,
    "Skill Gaps": skill_gaps,
    "AI Analysis": ai_output
}

final_output
