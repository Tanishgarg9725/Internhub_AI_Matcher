# %%
import os
import json
from dotenv import load_dotenv

# %%
student_profile = {
    "name": "Tanish Garg",
    "skills": [
        "Python",
        "Machine Learning",
        "Pandas",
        "SQL",
        "Data Analysis"
    ],
    "interests": [
        "AI",
        "Data Science",
        "Backend Development"
    ],
    "experience": "Built multiple ML projects and data analysis dashboards."
}

# %%
internship_description = {
    "role": "AI Intern",
    "required_skills": [
        "Python",
        "Machine Learning",
        "Deep Learning",
        "Docker",
        "Model Deployment"
    ],
    "description": """
    We are looking for an AI Intern to build, train and deploy machine learning models.
    Experience with Python, ML frameworks, and deployment tools is preferred.
    """
}

# %%
def calculate_ats_score(student_skills, required_skills):
    matched = set(student_skills).intersection(set(required_skills))
    score = (len(matched) / len(required_skills)) * 100
    return round(score, 2), list(matched)

# %%
ats_score, matched_skills = calculate_ats_score(
    student_profile["skills"],
    internship_description["required_skills"]
)

ats_score, matched_skills
# Out:
# (40.0, ['Machine Learning', 'Python'])

# %%
def find_skill_gaps(student_skills, required_skills):
    return list(set(required_skills) - set(student_skills))

# %%
skill_gaps = find_skill_gaps(
    student_profile["skills"],
    internship_description["required_skills"]
)

skill_gaps
# Out:
# ['Model Deployment', 'Deep Learning', 'Docker']

# %%
prompt = f"""
You are an AI career assistant.

Student skills: {student_profile['skills']}
Student experience: {student_profile['experience']}

Internship role: {internship_description['role']}
Required skills: {internship_description['required_skills']}

Tasks:
1. Match summary
2. Skill gaps
3. ATS feedback
4. Resume improvement tips
5. Final recommendation
"""

# %%
import google.generativeai as genai
from dotenv import load_dotenv
import os

# Load API key
load_dotenv("API.env")
GEMINI_API_KEY = os.getenv("GEMINI_API_KEY")

# Configure Gemini
genai.configure(api_key=GEMINI_API_KEY)

# FREE-TIER SAFE MODEL ✅
model = genai.GenerativeModel("models/gemini-flash-lite-latest")

response = model.generate_content(prompt)
ai_output = response.text

ai_output
# Out:
# D:\python310\pytorch-gpu-env\lib\site-packages\google\api_core\_python_version_support.py:275: FutureWarning: You are using a Python version (3.10.0) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# C:\Users\asus\AppData\Local\Temp\ipykernel_31036\868102263.py:1: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   import google.generativeai as genai
# 'This is a comprehensive analysis of the student\'s profile against the requirements for an AI Intern role.\n\n---\n\n## AI Intern Career Assessment\n\n### 1. Match Summary\n\n| Feature | Student Profile | AI Intern Requirements | Match Score | Notes |\n| :--- | :--- | :--- | :--- | :--- |\n| **Core Programming** | Python (Strong) | Python (Required) | **Excellent** | Direct match. Python is the foundation. |\n| **Core AI/ML** | Machine Learning (Strong) | Machine Learning (Required) | **Excellent** | Direct match. Student has practical project experience. |\n| **Data Handling** | Pandas, SQL (Strong) | (Implicitly Required for ML/Data Prep) | **Good** | Strong foundational data skills, though not explicitly listed in required skills. |\n| **Deep Learning** | *Not explicitly listed* | Deep Learning (Required) | **Partial** | This is the most significant gap. The student has ML experience, but DL proficiency needs to be confirmed/added. |\n| **MLOps/Ops** | *Not explicitly listed* | Docker, Model Deployment (Required) | **Major Gap** | No explicit mention of containerization or deployment experience. |\n| **Experience Level**| Multiple ML projects, Dashboards | AI Intern | **Good** | Practical project work is highly relevant for an intern role. |\n\n**Overall Match Assessment:** The student possesses a **strong foundation** in the core requirements (Python, ML, Data Analysis). However, there are **two critical technical gaps** (Deep Learning and MLOps/Deployment) that need to be addressed to fully align with the specified internship role.\n\n---\n\n### 2. Skill Gaps Analysis\n\nBased on the required skills versus the student\'s listed skills, here are the immediate gaps:\n\n1.  **Deep Learning (DL):** The student lists "Machine Learning," which is foundational, but "Deep Learning" (e.g., TensorFlow, PyTorch, CNNs, RNNs) is explicitly required.\n2.  **Docker:** This is essential for reproducible environments and often required for model serving/deployment in modern ML pipelines.\n3.  **Model Deployment:** This goes beyond building a model; it involves serving it (e.g., using Flask/Streamlit, cloud services like AWS SageMaker, or containerized deployment via Docker).\n\n**Actionable Recommendation:** The student must prioritize learning and demonstrating proficiency in these three areas, even if through focused personal projects.\n\n---\n\n### 3. ATS Feedback (Applicant Tracking System)\n\nThe current resume likely performs well on initial keyword matching due to the strong presence of "Python," "Machine Learning," and "Data Analysis."\n\n**Weaknesses Identified by ATS:**\n\n*   **Missing Keywords:** The ATS will likely filter out the application if it does not see **"Deep Learning," "Docker,"** and **"Model Deployment"** or synonyms (e.g., "Containerization," "Serving," "MLOps") in the experience section.\n*   **Dashboard Focus:** While "Pandas" is great, the emphasis on "Data Analysis Dashboards" might signal a BI/Data Analyst focus rather than a pure AI/ML Engineering focus, potentially causing lower relevancy scores for roles emphasizing model production.\n\n**How to Improve ATS Ranking:** Integrate the required keywords naturally into the project descriptions.\n\n*   *Example Change:* Instead of "Built an ML project using Python," try: "Developed a **Machine Learning** model utilizing **PyTorch/TensorFlow** for [Task], subsequently containerizing the model using **Docker** for scalable **Model Deployment**."\n\n---\n\n### 4. Resume Improvement Tips\n\nThe goal is to reframe the existing strong experience to directly address the required AI Intern skills.\n\n| Area | Current Implication (Likely) | Recommended Action |\n| :--- | :--- | :--- |\n| **Machine Learning Projects** | Focus on model accuracy and data insights. | **Reframe for Deployment:** Explicitly state the technologies used *after* model creation (e.g., Flask API, basic Docker setup). |\n| **Pandas/Data Analysis** | Good for feature engineering, but might overemph ...

# %%
final_output = {
    "ATS Score": ats_score,
    "Matched Skills": matched_skills,
    "Skill Gaps": skill_gaps,
    "AI Analysis": ai_output
}

final_output
# Out:
# {'ATS Score': 40.0,
#  'Matched Skills': ['Machine Learning', 'Python'],
#  'Skill Gaps': ['Model Deployment', 'Deep Learning', 'Docker'],
#  'AI Analysis': 'This is a comprehensive analysis of the student\'s profile against the requirements for an AI Intern role.\n\n---\n\n## AI Intern Career Assessment\n\n### 1. Match Summary\n\n| Feature | Student Profile | AI Intern Requirements | Match Score | Notes |\n| :--- | :--- | :--- | :--- | :--- |\n| **Core Programming** | Python (Strong) | Python (Required) | **Excellent** | Direct match. Python is the foundation. |\n| **Core AI/ML** | Machine Learning (Strong) | Machine Learning (Required) | **Excellent** | Direct match. Student has practical project experience. |\n| **Data Handling** | Pandas, SQL (Strong) | (Implicitly Required for ML/Data Prep) | **Good** | Strong foundational data skills, though not explicitly listed in required skills. |\n| **Deep Learning** | *Not explicitly listed* | Deep Learning (Required) | **Partial** | This is the most significant gap. The student has ML experience, but DL proficiency needs to be confirmed/added. |\n| **MLOps/Ops** | *Not explicitly listed* | Docker, Model Deployment (Required) | **Major Gap** | No explicit mention of containerization or deployment experience. |\n| **Experience Level**| Multiple ML projects, Dashboards | AI Intern | **Good** | Practical project work is highly relevant for an intern role. |\n\n**Overall Match Assessment:** The student possesses a **strong foundation** in the core requirements (Python, ML, Data Analysis). However, there are **two critical technical gaps** (Deep Learning and MLOps/Deployment) that need to be addressed to fully align with the specified internship role.\n\n---\n\n### 2. Skill Gaps Analysis\n\nBased on the required skills versus the student\'s listed skills, here are the immediate gaps:\n\n1.  **Deep Learning (DL):** The student lists "Machine Learning," which is foundational, but "Deep Learning" (e.g., TensorFlow, PyTorch, CNNs, RNNs) is explicitly required.\n2.  **Docker:** This is essential for reproducible environments and often required for model serving/deployment in modern ML pipelines.\n3.  **Model Deployment:** This goes beyond building a model; it involves serving it (e.g., using Flask/Streamlit, cloud services like AWS SageMaker, or containerized deployment via Docker).\n\n**Actionable Recommendation:** The student must prioritize learning and demonstrating proficiency in these three areas, even if through focused personal projects.\n\n---\n\n### 3. ATS Feedback (Applicant Tracking System)\n\nThe current resume likely performs well on initial keyword matching due to the strong presence of "Python," "Machine Learning," and "Data Analysis."\n\n**Weaknesses Identified by ATS:**\n\n*   **Missing Keywords:** The ATS will likely filter out the application if it does not see **"Deep Learning," "Docker,"** and **"Model Deployment"** or synonyms (e.g., "Containerization," "Serving," "MLOps") in the experience section.\n*   **Dashboard Focus:** While "Pandas" is great, the emphasis on "Data Analysis Dashboards" might signal a BI/Data Analyst focus rather than a pure AI/ML Engineering focus, potentially causing lower relevancy scores for roles emphasizing model production.\n\n**How to Improve ATS Ranking:** Integrate the required keywords naturally into the project descriptions.\n\n*   *Example Change:* Instead of "Built an ML project using Python," try: "Developed a **Machine Learning** model utilizing **PyTorch/TensorFlow** for [Task], subsequently containerizing the model using **Docker** for scalable **Model Deployment**."\n\n---\n\n### 4. Resume Improvement Tips\n\nThe goal is to reframe the existing strong experience to directly address the required AI Intern skills.\n\n| Area | Current Implication (Likely) | Recommended Action |\n| :--- | :--- | :--- |\n| **Machine Learning Projects** | Focus on model accuracy and data insights. | **Reframe for Deployment:** Explicitly state the technologies used *after* model creation (e.g., Flask API, basic Docker setup). |\n| **Pandas/Data Analysis** | Good for feature engineering, bu ...
